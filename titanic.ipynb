# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/Users/kcaster/titanic/train.csv', header=0)
df = train
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
test = pd.read_csv('/Users/kcaster/titanic/test.csv', header=0)

# %%
train.Age[:10].mean()
# Out:
# 28.111111111111111

# %%
import pylab as P
df[df.Survived == 0]['Age'].hist()
P.show()

# %%
df['Gender'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked  Gender
# 0      0  A/5 21171   7.2500   NaN        S       1
# 1      0   PC 17599  71.2833   C85        C       0

# %%
df.Age.median()
# Out:
# 28.0

# %%
median_ages = np.zeros((2,3))
median_ages
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
for i in range(0, 2):
    for j in range(0, 3):
        median_ages[i,j] = df[(df['Gender'] == i) & \
                              (df['Pclass'] == j+1)]['Age'].dropna().median()
 
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
df['AgeFill'] = df['Age']
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked  Gender  AgeFill
# 0      0  A/5 21171   7.2500   NaN        S       1       22
# 1      0   PC 17599  71.2833   C85        C       0       38

# %%
for i in range(0, 2):
    for j in range(0, 3):
        df.loc[ (df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1),\
                'AgeFill'] = median_ages[i,j]

# %%
df[ df['Age'].isnull() ][['Gender','Pclass','Age','AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5
# 29       1       3  NaN     25.0
# 31       0       1  NaN     35.0
# 32       0       3  NaN     21.5
# 36       1       3  NaN     25.0
# 42       1       3  NaN     25.0

# %%
df['AgeIsNull'] = pd.isnull(df.Age).astype(int)

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked  Gender  AgeFill  AgeIsNull  \
# 0      0  A/5 21171   7.2500   NaN        S       1       22          0
# 1      0   PC 17599  71.2833   C85        C       0       38          0
#
#    FamilySize
# 0           1
# 1           1

# %%
set(df['EmbarkPort'].values)
# Out:
# {-1, 0, 1, 2}

# %%
df['EmbarkPort'] = df['Embarked']
df[df.EmbarkPort.isnull()] = -1

# %%
set(df.Cabin)
# Out:
# {nan,
#  -1,
#  'A10',
#  'A14',
#  'A16',
#  'A19',
#  'A20',
#  'A23',
#  'A24',
#  'A26',
#  'A31',
#  'A32',
#  'A34',
#  'A36',
#  'A5',
#  'A6',
#  'A7',
#  'B101',
#  'B102',
#  'B18',
#  'B19',
#  'B20',
#  'B22',
#  'B3',
#  'B30',
#  'B35',
#  'B37',
#  'B38',
#  'B39',
#  'B4',
#  'B41',
#  'B42',
#  'B49',
#  'B5',
#  'B50',
#  'B51 B53 B55',
#  'B57 B59 B63 B66',
#  'B58 B60',
#  'B69',
#  'B71',
#  'B73',
#  'B77',
#  'B78',
#  'B79',
#  'B80',
#  'B82 B84',
#  'B86',
#  'B94',
#  'B96 B98',
#  'C101',
#  'C103',
#  'C104',
#  'C106',
#  'C110',
#  'C111',
#  'C118',
#  'C123',
#  'C124',
#  'C125',
#  'C126',
#  'C128',
#  'C148',
#  'C2',
#  'C22 C26',
#  'C23 C25 C27',
#  'C30',
#  'C32',
#  'C45',
#  'C46',
#  'C47',
#  'C49',
#  'C50',
#  'C52',
#  'C54',
#  'C62 C64',
#  'C65',
#  'C68',
#  'C7',
#  'C70',
#  'C78',
#  'C82',
#  'C83',
#  'C85',
#  'C86',
#  'C87',
#  'C90',
#  'C91',
#  'C92',
#  'C93',
#  'C95',
#  'C99',
#  'D',
#  'D10 D12',
#  'D11',
# ...

# %%
df['EmbarkPort'] = df['EmbarkPort'].map( {'C': 0, 'Q': 1, 'S' : 2, -1 : -1} )
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch     Ticket     Fare Cabin Embarked  Gender  AgeFill  AgeIsNull  \
# 0      0  A/5 21171   7.2500   NaN        S       1       22          0
# 1      0   PC 17599  71.2833   C85        C       0       38          0
#
#    FamilySize  EmbarkPort
# 0           1           2
# 1           1           0
